# %%
# Import necessary libraries
import os
import pandas as pd
from utils.binance_data import get_historical_klines, get_usdt_symbols, get_symbols_from_list

# Set options to display all columns and float format to 2 decimal places
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

# %% [markdown]
# #### Definimos la funcion para obtener la data historica desde la API de Binance

# %%
def collect_binance_data(start_date, end_date, interval="1d", output_file=None, symbols=None):
    """Collect historical data for all USDT pairs from Binance.
    
    Args:
        start_date (str): Start date in 'YYYY-MM-DD' format
        end_date (str): End date in 'YYYY-MM-DD' format
        interval (str, optional): Kline interval. Defaults to "1d"
        output_file (str, optional): Output file path. If None, generates default name
        symbols (list, optional): List of symbols to collect data for. If None, fetches all USDT pairs.
    """
    if output_file is None:
        if symbols is None:
            output_file = f'binance_usdt_pairs_{start_date}_{end_date}_{interval}.csv'

        else:
            output_file = f'binance_{symbols}_{start_date}_{end_date}_{interval}.csv'

    # Get all USDT trading pairs if no symbols are provided
    if symbols is None:
        symbols = get_usdt_symbols()
        print(f"Found {len(symbols)} USDT trading pairs")

    # Initialize an empty DataFrame to store all data
    all_pairs_df = pd.DataFrame()

    # Check if we have existing data
    if os.path.exists(output_file):
        all_pairs_df = pd.read_csv(output_file)
        all_pairs_df['open_time'] = pd.to_datetime(all_pairs_df['open_time'])
        all_pairs_df.set_index(['symbol', 'open_time'], inplace=True)

    # Collect data for each symbol
    for symbol in symbols:
        try:
            print(f"Collecting data for {symbol}...")
            
            last_timestamp = None
            if not all_pairs_df.empty and symbol in all_pairs_df.index.get_level_values('symbol'):
                symbol_data = all_pairs_df.loc[symbol]
                last_timestamp = int(symbol_data.index[-1].timestamp() * 1000)
                print(f"Continuing from {symbol_data.index[-1]} for {symbol}")
            
            df = get_historical_klines(symbol, interval, start_date, end_date, last_timestamp)
            
            if df is not None and not df.empty:
                df['symbol'] = symbol
                
                if not all_pairs_df.empty and symbol in all_pairs_df.index.get_level_values('symbol'):
                    all_pairs_df = all_pairs_df.drop(symbol, level='symbol')
                
                df.reset_index(inplace=True)
                df.set_index(['symbol', 'open_time'], inplace=True)
                
                all_pairs_df = pd.concat([all_pairs_df, df])
                all_pairs_df.to_csv(output_file)
                print(f"Data saved for {symbol}")
                
        except Exception as e:
            print(f"Error collecting data for {symbol}: {str(e)}")

    # Final save and sort
    if not all_pairs_df.empty:
        all_pairs_df.sort_index(inplace=True)
        all_pairs_df.to_csv(output_file)
        print(f"\nAll data has been saved to {output_file}")

# %% [markdown]
# #### Obtenemos los pares en USDT de la API de Binance

# %%
# Define parameters
start_date = "2018-12-31"
end_date = "2024-01-01"
interval = "1d"
output_file = f"binance_usdt_pairs_{start_date}_{end_date}_{interval}.csv"

# Check if file exists, if not then collect historical data from Binance API
if not os.path.exists(output_file):
    collect_binance_data(start_date=start_date, end_date=end_date, interval=interval, output_file=None, symbols=None) # 33m 54.4s

# %%
data = pd.read_csv("binance_usdt_pairs_2018-12-31_2024-01-01_1d.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426165 entries, 0 to 426164
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   symbol           426165 non-null  object
#  1   open_time        426165 non-null  object
#  2   open             426165 non-null  float64
#  3   high             426165 non-null  float64
#  4   low              426165 non-null  float64
#  5   close            426165 non-null  float64
#  6   volume           426165 non-null  float64
#  7   close_time       426165 non-null  object
#  8   quote_volume     426165 non-null  float64
#  9   num_trades       426165 non-null  int64
#  10  taker_base_vol   426165 non-null  float64
#  11  taker_quote_vol  426165 non-null  float64
#  12  ignore           426165 non-null  int64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 42.3+ MB

# %%
# symbol: Trading pair symbol (e.g., "BTCUSDT")
# open_time: Start time of the candlestick period
# open: Opening price of the period
# high: Highest price during the period
# low: Lowest price during the period
# close: Closing price of the period
# volume: Total trading volume in base asset
# close_time: End time of the candlestick period
# quote_volume: Total trading volume in quote asset (USDT)
# num_trades: Number of trades executed in this period
# taker_base_vol: Volume of base asset bought by takers (market orders)
# taker_quote_vol: Volume of quote asset (USDT) bought by takers
# ignore: Unused column from Binance API (can be ignored)

data.head()
# Out:
#          symbol   open_time  open  high  low  close          volume  \
# 0  1000SATSUSDT  2023-12-12  0.00  0.00 0.00   0.00 624844140259.00
# 1  1000SATSUSDT  2023-12-13  0.00  0.00 0.00   0.00 317546611755.00
# 2  1000SATSUSDT  2023-12-14  0.00  0.00 0.00   0.00 778688810259.00
# 3  1000SATSUSDT  2023-12-15  0.00  0.00 0.00   0.00 902204913462.00
# 4  1000SATSUSDT  2023-12-16  0.00  0.00 0.00   0.00 405020284175.00
#
#                 close_time  quote_volume  num_trades  taker_base_vol  \
# 0  2023-12-12 23:59:59.999  340399289.88      995522 318852251409.00
# 1  2023-12-13 23:59:59.999  157167392.37      444221 158103387848.00
# 2  2023-12-14 23:59:59.999  511889240.81     1390517 399140907213.00
# 3  2023-12-15 23:59:59.999  732922339.08     2325998 450689519636.00
# 4  2023-12-16 23:59:59.999  312792279.99      940263 196177438805.00
#
#    taker_quote_vol  ignore
# 0     174388930.76       0
# 1      78333443.71       0
# 2     262301084.13       0
# 3     367398491.91       0
# 4     151753298.50       0

# %%
# Convert time columns to datetime
data['open_time'] = pd.to_datetime(data['open_time'])
data['close_time'] = pd.to_datetime(data['close_time'])

data.describe(include='all')
# Out:
#          symbol                      open_time      open      high       low  \
# count    426165                         426165 426165.00 426165.00 426165.00
# unique      473                            NaN       NaN       NaN       NaN
# top     XLMUSDT                            NaN       NaN       NaN       NaN
# freq       1827                            NaN       NaN       NaN       NaN
# mean        NaN  2022-03-19 02:04:48.547393280    217.43    225.13    209.45
# min         NaN            2019-01-01 00:00:00      0.00      0.00      0.00
# 25%         NaN            2021-05-26 00:00:00      0.08      0.08      0.08
# 50%         NaN            2022-05-01 00:00:00      0.56      0.60      0.53
# 75%         NaN            2023-03-11 00:00:00      3.82      4.05      3.61
# max         NaN            2024-01-01 00:00:00  82875.44  95000.00  66222.40
# std         NaN                            NaN   2428.07   2511.68   2340.12
#
#            close             volume                     close_time  \
# count  426165.00          426165.00                         426165
# unique       NaN                NaN                            NaN
# top          NaN                NaN                            NaN
# freq         NaN                NaN                            NaN
# mean      217.50     49288942974.14  2022-03-20 02:04:25.605836288
# min         0.00               0.00     2019-01-01 23:59:59.999000
# 25%         0.08          868804.62  2021-05-26 23:59:59.999000064
# 50%         0.56         6024896.43  2022-05-01 23:59:59.999000064
# 75%         3.81        41682675.44  2023-03-11 23:59:59.999000064
# max     82885.12 246104304402694.00     2024-01-01 23:59:59.999000
# std      2429.38   1472722496155.06                            NaN
#
#          quote_volume  num_trades     taker_base_vol  taker_quote_vol  \
# count       426165.00   426165.00          426165.00        426165.00
# unique            NaN         NaN                NaN              NaN
# top               NaN         NaN                NaN              NaN
# freq              NaN         NaN                NaN              NaN
# mean      34606491.37    60289.52     24396435277.07      17164146.88
# min              0.00        0.00               0.00             0.00
# 25%         859546.32     5720.00          416538.76        410377.34
# 50%        2977451.84    15285.00         2895703.00       1447073.42
# 75%       11329649.28    43301.00        20264664.90       5576163.32
# max    17598561857.08 15920580.00 122064332166743.00    9013969074.85
# std      240939261.73   243214.01    739118040236.16     119822253.99
#
#           ignore
# count  426165.00
# unique       NaN
# top          NaN
# freq         NaN
# mean        0.00
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         0.00
# std         0.00

# %% [markdown]
# #### Obtenemos los pares correspondientes a los pares de trading

# %%
# Get unique symbols without USDT
symbols = data['symbol'].unique()
symbols = [s.replace('USDT', '') for s in symbols]

# Generate all possible pairs
pairs = []
for i in range(len(symbols)):
    for j in range(i+1, len(symbols)):
        # Add both combinations for each pair
        pairs.append(symbols[i] + symbols[j])
        pairs.append(symbols[j] + symbols[i])

print(f"Total number of possible trading pairs: {len(pairs)}")
print("\nFirst 10 pairs as example:")
print(pairs[:10])
# Out:
# Total number of possible trading pairs: 223256
#
# First 10 pairs as example:
# ['1000SATS1INCHDOWN', '1INCHDOWN1000SATS', '1000SATS1INCHUP', '1INCHUP1000SATS', '1000SATS1INCH', '1INCH1000SATS', '1000SATSAAVEDOWN', 'AAVEDOWN1000SATS', '1000SATSAAVEUP', 'AAVEUP1000SATS']

# %%
len(set(pairs))
# Out:
# 223244

# %%
existing_pairs = get_symbols_from_list(set(pairs))
len(existing_pairs)
# Out:
# 1541

# %%
start_date = "2018-12-31"
end_date = "2024-01-01"
interval = "1d"
output_file = f'binance_pairs_{start_date}_{end_date}_{interval}.csv'

# Check if file exists, if not then collect historical data from Binance API
if not os.path.exists(output_file):
    collect_binance_data(start_date=start_date, end_date=end_date, interval=interval,
                        output_file=output_file, symbols=existing_pairs) # 202m 22.2s
# Out:
# Collecting data for NEBLBTC...
# Data saved for NEBLBTC
# Collecting data for OPFDUSD...
# Data saved for OPFDUSD
# Collecting data for MOBBUSD...
# Data saved for MOBBUSD
# Collecting data for LUNAGBP...
# Data saved for LUNAGBP
# Collecting data for OAXETH...
# Data saved for OAXETH
# Collecting data for OXTBTC...
# Data saved for OXTBTC
# Collecting data for AGLDBUSD...
# Data saved for AGLDBUSD
# Collecting data for JSTBNB...
# Data saved for JSTBNB
# Collecting data for ALGOTUSD...
# Data saved for ALGOTUSD
# Collecting data for FARMBTC...
# Data saved for FARMBTC
# Collecting data for LENDETH...
# Data saved for LENDETH
# Collecting data for IOSTETH...
# Data saved for IOSTETH
# Collecting data for FETUSDC...
# Collecting data for SHIBEUR...
# Data saved for SHIBEUR
# Collecting data for MATICTUSD...
# Data saved for MATICTUSD
# Collecting data for CAKEAUD...
# Data saved for CAKEAUD
# Collecting data for CHZGBP...
# Data saved for CHZGBP
# Collecting data for NUAUD...
# Data saved for NUAUD
# Collecting data for LTCETH...
# Data saved for LTCETH
# Collecting data for DOGEBUSD...
# Data saved for DOGEBUSD
# Collecting data for ETCBUSD...
# Data saved for ETCBUSD
# Collecting data for CLVBUSD...
# Data saved for CLVBUSD
# Collecting data for ALGOFDUSD...
# Data saved for ALGOFDUSD
# Collecting data for FRONTETH...
# Data saved for FRONTETH
# Collecting data for ALGOPAX...
# Data saved for ALGOPAX
# Collecting data for XMRETH...
# Data saved for XMRETH
# Collecting data for ANCBUSD...
# Data saved for ANCBUSD
# Collecting data for TBUSD...
# Data saved for TBUSD
# Collecting data for STPTBTC...
# Data saved for STPTBTC
# Collecting data for JUVBUSD...
# Data saved for JUVBUSD
# Collecting data for ETHBEARBUSD...
# Data saved for ETHBEARBUSD
# Collecting data for BETAETH...
# Data saved for BETAETH
# Collecting data for HOTBNB...
# Data saved for HOTBNB
# Collecting data for RGTBUSD...
# Data saved for RGTBUSD
# Collecting data for LAZIOEUR...
# Data saved for LAZIOEUR
# Collecting data for ALPACABUSD...
# Data saved for ALPACABUSD
# Collecting data for BANDBTC...
# Data saved for BANDBTC
# Collecting data for ONEBUSD...
# Data saved for ONEBUSD
# Collecting data for OOKIBUSD...
# Data saved for OOKIBUSD
# Collecting data for C98BNB...
# Data saved for C98BNB
# Collecting data for USDSUSDC...
# Data saved for USDSUSDC
# Collecting data for ERDBUSD...
# Data saved for ERDBUSD
# Collecting data for ADAETH...
# Data saved for ADAETH
# Collecting data for SNTBTC...
# Data saved for SNTBTC
# Collecting data for THETABNB...
# Data saved for THETABNB
# Collecting data for ANKRBTC...
# Data saved for ANKRBTC
# Collecting data for CKBBUSD...
# Data saved for CKBBUSD
# Collecting data for KNCBTC...
# Data saved for KNCBTC
# Collecting data for TRUBUSD...
# Data saved for TRUBUSD
# Collecting data for ZECPAX...
# Data saved for ZECPAX
# Collecting data for BATPAX...
# Data saved for BATPAX
# Collecting data for TVKBTC...
# Data saved for TVKBTC
# Collecting data for RNDRFDUSD...
# Data saved for RNDRFDUSD
# Collecting data for KMDETH...
# Data saved for KMDETH
# Collecting data for DGBBTC...
# Data saved for DGBBTC
# Collecting data for GALBUSD...
# Data saved for GALBUSD
# Collecting data for GBPBUSD...
# Data saved for GBPBUSD
# Collecting data for AIONETH...
# Data saved for AIONETH
# Collecting data for BNXBNB...
# Data saved for BNXBNB
# Collecting data for DOGEEUR...
# Data saved for DOGEEUR
# Collecting data for BALBNB...
# Data saved for BALBNB
# Collecting data for GALBNB...
# Data saved for GALBNB
# Collecting data for TIAUSDC...
# Collecting data for MCBTC...
# Data saved for MCBTC
# Collecting data for MDXBUSD...
# Data saved for MDXBUSD
# Collecting data for INJBNB...
# Data saved for INJBNB
# Collecting data for SEIBNB...
# Data saved for SEIBNB
# Collecting data for THETAFDUSD...
# Collecting data for MATICAUD...
# Data saved for MATICAUD
# Collecting data for SANDETH...
# Data saved for SANDETH
# Collecting data for MAVTUSD...
# Data saved for MAVTUSD
# Collecting data for LITBTC...
# Data saved for LITBTC
# Collecting data for ACABUSD...
# Data saved for ACABUSD
# Collecting data for GALAAUD...
# Data saved for GALAAUD
# Collecting data for RENBTC...
# Data saved for RENBTC
# Collecting data for BLZBUSD...
# Data saved for BLZBUSD
# Collecting data for WAVESBUSD...
# Data saved for WAVESBUSD
# Collecting data for FORTHBUSD...
# Data saved for FORTHBUSD
# Collecting data for BNXBTC...
# Data saved for BNXBTC
# Collecting data for FTMFDUSD...
# Data saved for FTMFDUSD
# Collecting data for STXFDUSD...
# Collecting data for DOCKBTC...
# Data saved for DOCKBTC
# Collecting data for RUNEETH...
# Data saved for RUNEETH
# Collecting data for DNTETH...
# Data saved for DNTETH
# Collecting data for QNTBNB...
# Data saved for QNTBNB
# Collecting data for WTCBNB...
# Data saved for WTCBNB
# Collecting data for GASBTC...
# Data saved for GASBTC
# Collecting data for KLAYBUSD...
# Data saved for KLAYBUSD
# Collecting data for ALGOBUSD...
# Data saved for ALGOBUSD
# Collecting data for PERPBTC...
# Data saved for PERPBTC
# Collecting data for NEOBNB...
# Data saved for NEOBNB
# Collecting data for BALBTC...
# Data saved for BALBTC
# Collecting data for MOVRBNB...
# Data saved for MOVRBNB
# Collecting data for SANDAUD...
# Data saved for SANDAUD
# Collecting data for GXSBNB...
# Data saved for GXSBNB
# Collecting data for KSMBUSD...
# Data saved for KSMBUSD
# Collecting data for ONEUSDC...
# Data saved for ONEUSDC
# Collecting data for WLDFDUSD...
# Data saved for WLDFDUSD
# Collecting data for GHSTETH...
# Data saved for GHSTETH
# Collecting data for PEPETUSD...
# Data saved for PEPETUSD
# Collecting data for JASMYBTC...
# Data saved for JASMYBTC
# Collecting data for BCHABCBTC...
# Data saved for BCHABCBTC
# Collecting data for GNOBUSD...
# Data saved for GNOBUSD
# Collecting data for DOTEUR...
# Data saved for DOTEUR
# Collecting data for YFIBTC...
# Data saved for YFIBTC
# Collecting data for KAVABNB...
# Data saved for KAVABNB
# Collecting data for NBSBTC...
# Data saved for NBSBTC
# Collecting data for QUICKBTC...
# Data saved for QUICKBTC
# Collecting data for GTOBTC...
# Data saved for GTOBTC
# Collecting data for BANDBNB...
# Data saved for BANDBNB
# Collecting data for FISBUSD...
# Data saved for FISBUSD
# Collecting data for SCBTC...
# Data saved for SCBTC
# Collecting data for ARPABUSD...
# Data saved for ARPABUSD
# Collecting data for EURUSDC...
# Collecting data for KNCETH...
# Data saved for KNCETH
# Collecting data for BTCAEUR...
# Data saved for BTCAEUR
# Collecting data for MEMETUSD...
# Data saved for MEMETUSD
# Collecting data for KEEPBTC...
# Data saved for KEEPBTC
# Collecting data for DIABUSD...
# Data saved for DIABUSD
# Collecting data for SUPERBTC...
# Data saved for SUPERBTC
# Collecting data for BCHABCPAX...
# Data saved for BCHABCPAX
# Collecting data for APEEUR...
# Data saved for APEEUR
# Collecting data for DODOBUSD...
# Data saved for DODOBUSD
# Collecting data for DATABUSD...
# Data saved for DATABUSD
# Collecting data for BNBEUR...
# Data saved for BNBEUR
# Collecting data for QTUMBTC...
# Data saved for QTUMBTC
# Collecting data for COTIBTC...
# Data saved for COTIBTC
# Collecting data for PROMBUSD...
# Data saved for PROMBUSD
# Collecting data for LOOMBNB...
# Data saved for LOOMBNB
# Collecting data for CFXTUSD...
# Data saved for CFXTUSD
# Collecting data for ARKETH...
# Data saved for ARKETH
# Collecting data for AIONBTC...
# Data saved for AIONBTC
# Collecting data for DASHBTC...
# Data saved for DASHBTC
# Collecting data for OOKIBNB...
# Data saved for OOKIBNB
# Collecting data for COTIBUSD...
# Data saved for COTIBUSD
# Collecting data for GRTETH...
# Data saved for GRTETH
# Collecting data for CAKEGBP...
# Data saved for CAKEGBP
# Collecting data for RDNTBTC...
# Data saved for RDNTBTC
# Collecting data for HIVEBNB...
# Data saved for HIVEBNB
# Collecting data for CVPETH...
# Data saved for CVPETH
# Collecting data for JTOUSDC...
# Collecting data for IDEXBUSD...
# Data saved for IDEXBUSD
# Collecting data for PHBBUSD...
# Data saved for PHBBUSD
# Collecting data for XNOBUSD...
# Data saved for XNOBUSD
# Collecting data for ETHUST...
# Data saved for ETHUST
# Collecting data for QNTBTC...
# Data saved for QNTBTC
# Collecting data for DREPBUSD...
# Data saved for DREPBUSD
# Collecting data for LUNABTC...
# Data saved for LUNABTC
# Collecting data for FISBTC...
# Data saved for FISBTC
# Collecting data for MLNBUSD...
# Data saved for MLNBUSD
# Collecting data for DFETH...
# Data saved for DFETH
# Collecting data for RDNTTUSD...
# Data saved for RDNTTUSD
# Collecting data for NFPBTC...
# Data saved for NFPBTC
# Collecting data for CRVBUSD...
# Data saved for CRVBUSD
# Collecting data for POWRBTC...
# Data saved for POWRBTC
# Collecting data for BURGERETH...
# Data saved for BURGERETH
# Collecting data for AAVEUSDC...
# Collecting data for QIBTC...
# Data saved for QIBTC
# Collecting data for WRXBTC...
# Data saved for WRXBTC
# Collecting data for PSGBTC...
# Data saved for PSGBTC
# Collecting data for BTCGBP...
# Data saved for BTCGBP
# Collecting data for BTTBNB...
# Data saved for BTTBNB
# Collecting data for NANOBNB...
# Data saved for NANOBNB
# Collecting data for BONDBTC...
# Data saved for BONDBTC
# Collecting data for AAVEFDUSD...
# Collecting data for ICPFDUSD...
# Collecting data for NEOETH...
# Data saved for NEOETH
# Collecting data for MATICBUSD...
# Data saved for MATICBUSD
# Collecting data for MAGICBTC...
# Data saved for MAGICBTC
# Collecting data for DARETH...
# Data saved for DARETH
# Collecting data for COCOSBUSD...
# Data saved for COCOSBUSD
# Collecting data for NKNBUSD...
# Data saved for NKNBUSD
# Collecting data for POLSBTC...
# Data saved for POLSBTC
# Collecting data for ZECETH...
# Data saved for ZECETH
# Collecting data for ALPINEEUR...
# Data saved for ALPINEEUR
# Collecting data for ATOMTUSD...
# Data saved for ATOMTUSD
# Collecting data for NEXOBTC...
# Data saved for NEXOBTC
# Collecting data for CELOBUSD...
# Data saved for CELOBUSD
# Collecting data for TRXTUSD...
# Data saved for TRXTUSD
# Collecting data for PYRBTC...
# Data saved for PYRBTC
# Collecting data for NULSBNB...
# Data saved for NULSBNB
# Collecting data for TUSDT...
# Data saved for TUSDT
# Collecting data for BEAMBNB...
# Data saved for BEAMBNB
# Collecting data for PYRBUSD...
# Data saved for PYRBUSD
# Collecting data for SUIBNB...
# Data saved for SUIBNB
# Collecting data for BTCUSDC...
# Data saved for BTCUSDC
# Collecting data for DARBUSD...
# Data saved for DARBUSD
# Collecting data for ARDRETH...
# Data saved for ARDRETH
# Collecting data for XLMEUR...
# Data saved for XLMEUR
# Collecting data for ACEFDUSD...
# Data saved for ACEFDUSD
# Collecting data for GTOTUSD...
# Data saved for GTOTUSD
# Collecting data for XLMPAX...
# Data saved for XLMPAX
# Collecting data for PEOPLEBNB...
# Data saved for PEOPLEBNB
# Collecting data for PEOPLEETH...
# Data saved for PEOPLEETH
# Collecting data for EURAEUR...
# Data saved for EURAEUR
# Collecting data for OXTBUSD...
# Data saved for OXTBUSD
# Collecting data for PHBBNB...
# Data saved for PHBBNB
# Collecting data for JASMYBNB...
# Data saved for JASMYBNB
# Collecting data for FTTBNB...
# Data saved for FTTBNB
# Collecting data for ETHDAI...
# Data saved for ETHDAI
# Collecting data for XLMTUSD...
# Data saved for XLMTUSD
# Collecting data for XRPBEARBUSD...
# Data saved for XRPBEARBUSD
# Collecting data for SANDBUSD...
# Data saved for SANDBUSD
# Collecting data for OPETH...
# Data saved for OPETH
# Collecting data for SUITUSD...
# Data saved for SUITUSD
# Collecting data for BTTCBUSD...
# Data saved for BTTCBUSD
# Collecting data for LENDBKRW...
# Data saved for LENDBKRW
# Collecting data for LINKEUR...
# Data saved for LINKEUR
# Collecting data for DOTFDUSD...
# Data saved for DOTFDUSD
# Collecting data for LTCGBP...
# Data saved for LTCGBP
# Collecting data for BTTTRX...
# Data saved for BTTTRX
# Collecting data for GASFDUSD...
# Data saved for GASFDUSD
# Collecting data for ROSEETH...
# Data saved for ROSEETH
# Collecting data for BARBTC...
# Data saved for BARBTC
# Collecting data for AMBBNB...
# Data saved for AMBBNB
# Collecting data for XVGBUSD...
# Data saved for XVGBUSD
# Collecting data for DUSKBNB...
# Data saved for DUSKBNB
# Collecting data for GTOBNB...
# Data saved for GTOBNB
# Collecting data for ONTPAX...
# Data saved for ONTPAX
# Collecting data for PEOPLEBTC...
# Data saved for PEOPLEBTC
# Collecting data for ETCEUR...
# Data saved for ETCEUR
# Collecting data for LRCBTC...
# Data saved for LRCBTC
# Collecting data for CLVBNB...
# Data saved for CLVBNB
# Collecting data for FUNBNB...
# Data saved for FUNBNB
# Collecting data for LPTBUSD...
# Data saved for LPTBUSD
# Collecting data for AXSAUD...
# Data saved for AXSAUD
# Collecting data for DOGEPAX...
# Data saved for DOGEPAX
# Collecting data for ATABUSD...
# Data saved for ATABUSD
# Collecting data for PAXBNB...
# Collecting data for BTCAUD...
# Data saved for BTCAUD
# Collecting data for XRPTUSD...
# Data saved for XRPTUSD
# Collecting data for SOLBNB...
# Data saved for SOLBNB
# Collecting data for BURGERBNB...
# Data saved for BURGERBNB
# Collecting data for MEMEETH...
# Data saved for MEMEETH
# Collecting data for FXSBTC...
# Data saved for FXSBTC
# Collecting data for BONDBUSD...
# Data saved for BONDBUSD
# Collecting data for HCBTC...
# Data saved for HCBTC
# Collecting data for NULSBUSD...
# Data saved for NULSBUSD
# Collecting data for ZENBTC...
# Data saved for ZENBTC
# Collecting data for XZCBTC...
# Data saved for XZCBTC
# Collecting data for ETHBTC...
# Data saved for ETHBTC
# Collecting data for BAKEBUSD...
# Data saved for BAKEBUSD
# Collecting data for EOSBEARBUSD...
# Data saved for EOSBEARBUSD
# Collecting data for FRONTBUSD...
# Data saved for FRONTBUSD
# Collecting data for AUCTIONBTC...
# Data saved for AUCTIONBTC
# Collecting data for ALGOBTC...
# Data saved for ALGOBTC
# Collecting data for MATICEUR...
# Data saved for MATICEUR
# Collecting data for YFIBUSD...
# Data saved for YFIBUSD
# Collecting data for INJBTC...
# Data saved for INJBTC
# Collecting data for SCRTETH...
# Data saved for SCRTETH
# Collecting data for EURBUSD...
# Data saved for EURBUSD
# Collecting data for USDSBUSDS...
# Data saved for USDSBUSDS
# Collecting data for RUNEAUD...
# Data saved for RUNEAUD
# Collecting data for BLURBTC...
# Data saved for BLURBTC
# Collecting data for KEEPBNB...
# Data saved for KEEPBNB
# Collecting data for PENDLEUSDC...
# Collecting data for QIBNB...
# Data saved for QIBNB
# Collecting data for XZCETH...
# Data saved for XZCETH
# Collecting data for HOTBUSD...
# Data saved for HOTBUSD
# Collecting data for MCOETH...
# Data saved for MCOETH
# Collecting data for OCEANBUSD...
# Data saved for OCEANBUSD
# Collecting data for ENJBTC...
# Data saved for ENJBTC
# Collecting data for MBLBUSD...
# Data saved for MBLBUSD
# Collecting data for FORBNB...
# Data saved for FORBNB
# Collecting data for FIROETH...
# Data saved for FIROETH
# Collecting data for TOMOBUSD...
# Data saved for TOMOBUSD
# Collecting data for ZILBUSD...
# Data saved for ZILBUSD
# Collecting data for ARFDUSD...
# Collecting data for ZECTUSD...
# Data saved for ZECTUSD
# Collecting data for PORTOEUR...
# Data saved for PORTOEUR
# Collecting data for IOTXBTC...
# Data saved for IOTXBTC
# Collecting data for KEYETH...
# Data saved for KEYETH
# Collecting data for NKNBTC...
# Data saved for NKNBTC
# Collecting data for ETCETH...
# Data saved for ETCETH
# Collecting data for CVCETH...
# Data saved for CVCETH
# Collecting data for ARKMTUSD...
# Data saved for ARKMTUSD
# Collecting data for XTZBNB...
# Data saved for XTZBNB
# Collecting data for TFUELBUSD...
# Data saved for TFUELBUSD
# Collecting data for HARDBNB...
# Data saved for HARDBNB
# Collecting data for FTMETH...
# Data saved for FTMETH
# Collecting data for ZILETH...
# Data saved for ZILETH
# Collecting data for TRBBNB...
# Data saved for TRBBNB
# Collecting data for REIBNB...
# Data saved for REIBNB
# Collecting data for ENSBNB...
# Data saved for ENSBNB
# Collecting data for UNFIBNB...
# Data saved for UNFIBNB
# Collecting data for KEYBUSD...
# Data saved for KEYBUSD
# Collecting data for APEGBP...
# Data saved for APEGBP
# Collecting data for ETHFDUSD...
# Data saved for ETHFDUSD
# Collecting data for ARBTUSD...
# Data saved for ARBTUSD
# Collecting data for AVAXTUSD...
# Data saved for AVAXTUSD
# Collecting data for YGGBUSD...
# Data saved for YGGBUSD
# Collecting data for ETHBKRW...
# Data saved for ETHBKRW
# Collecting data for PEPEFDUSD...
# Collecting data for TRXEUR...
# Data saved for TRXEUR
# Collecting data for RNDRBUSD...
# Data saved for RNDRBUSD
# Collecting data for WINBNB...
# Data saved for WINBNB
# Collecting data for AUCTIONFDUSD...
# Data saved for AUCTIONFDUSD
# Collecting data for IOTXBUSD...
# Data saved for IOTXBUSD
# Collecting data for GLMRBTC...
# Data saved for GLMRBTC
# Collecting data for ADAGBP...
# Data saved for ADAGBP
# Collecting data for BUSDDAI...
# Data saved for BUSDDAI
# Collecting data for MASKBUSD...
# Data saved for MASKBUSD
# Collecting data for BNBAUD...
# Data saved for BNBAUD
# Collecting data for RUNEBTC...
# Data saved for RUNEBTC
# Collecting data for ETHEUR...
# Data saved for ETHEUR
# Collecting data for MITHBTC...
# Data saved for MITHBTC
# Collecting data for FILFDUSD...
# Data saved for FILFDUSD
# Collecting data for XVSBNB...
# Data saved for XVSBNB
# Collecting data for RLCBUSD...
# Data saved for RLCBUSD
# Collecting data for WAXPBTC...
# Data saved for WAXPBTC
# Collecting data for FUNETH...
# Data saved for FUNETH
# Collecting data for GALBTC...
# Data saved for GALBTC
# Collecting data for IOTXETH...
# Data saved for IOTXETH
# Collecting data for MINABTC...
# Data saved for MINABTC
# Collecting data for NKNBNB...
# Data saved for NKNBNB
# Collecting data for CVXBUSD...
# Data saved for CVXBUSD
# Collecting data for GMXBTC...
# Data saved for GMXBTC
# Collecting data for RVNBUSD...
# Data saved for RVNBUSD
# Collecting data for PIVXBTC...
# Data saved for PIVXBTC
# Collecting data for BARBUSD...
# Data saved for BARBUSD
# Collecting data for ALICEBTC...
# Data saved for ALICEBTC
# Collecting data for DOTGBP...
# Data saved for DOTGBP
# Collecting data for XLMBNB...
# Data saved for XLMBNB
# Collecting data for UNIEUR...
# Data saved for UNIEUR
# Collecting data for BZRXBNB...
# Data saved for BZRXBNB
# Collecting data for GRTEUR...
# Data saved for GRTEUR
# Collecting data for BONKUSDC...
# Collecting data for MBLBNB...
# Data saved for MBLBNB
# Collecting data for XECBUSD...
# Data saved for XECBUSD
# Collecting data for YGGUSDC...
# Collecting data for DARBTC...
# Data saved for DARBTC
# Collecting data for XNOETH...
# Data saved for XNOETH
# Collecting data for YFIBNB...
# Data saved for YFIBNB
# Collecting data for TIAFDUSD...
# Collecting data for LOOMBUSD...
# Data saved for LOOMBUSD
# Collecting data for BCHPAX...
# Data saved for BCHPAX
# Collecting data for RVNBTC...
# Data saved for RVNBTC
# Collecting data for UNIETH...
# Data saved for UNIETH
# Collecting data for IDBTC...
# Data saved for IDBTC
# Collecting data for LDOFDUSD...
# Collecting data for SOLGBP...
# Data saved for SOLGBP
# Collecting data for RUNEFDUSD...
# Data saved for RUNEFDUSD
# Collecting data for NMRBUSD...
# Data saved for NMRBUSD
# Collecting data for GMTBTC...
# Data saved for GMTBTC
# Collecting data for REEFBUSD...
# Data saved for REEFBUSD
# Collecting data for BTCBUSD...
# Data saved for BTCBUSD
# Collecting data for BTCUSDP...
# Data saved for BTCUSDP
# Collecting data for PENDLEBTC...
# Data saved for PENDLEBTC
# Collecting data for NEBLBUSD...
# Data saved for NEBLBUSD
# Collecting data for ZILEUR...
# Data saved for ZILEUR
# Collecting data for ATOMBNB...
# Data saved for ATOMBNB
# Collecting data for HBARBNB...
# Data saved for HBARBNB
# Collecting data for DUSKPAX...
# Data saved for DUSKPAX
# Collecting data for LTCTUSD...
# Data saved for LTCTUSD
# Collecting data for IOTAETH...
# Data saved for IOTAETH
# Collecting data for BUSDBKRW...
# Data saved for BUSDBKRW
# Collecting data for DATABTC...
# Data saved for DATABTC
# Collecting data for ALICEBUSD...
# Data saved for ALICEBUSD
# Collecting data for ERDUSDC...
# Data saved for ERDUSDC
# Collecting data for CTXCBUSD...
# Data saved for CTXCBUSD
# Collecting data for MITHBNB...
# Data saved for MITHBNB
# Collecting data for YFIIBNB...
# Data saved for YFIIBNB
# Collecting data for EGLDFDUSD...
# Data saved for EGLDFDUSD
# Collecting data for SXPGBP...
# Data saved for SXPGBP
# Collecting data for HNTBUSD...
# Data saved for HNTBUSD
# Collecting data for XVSBUSD...
# Data saved for XVSBUSD
# Collecting data for BLZBNB...
# Data saved for BLZBNB
# Collecting data for ENSFDUSD...
# Collecting data for AXSBUSD...
# Data saved for AXSBUSD
# Collecting data for STMXETH...
# Data saved for STMXETH
# Collecting data for IRISBTC...
# Data saved for IRISBTC
# Collecting data for WNXMBUSD...
# Data saved for WNXMBUSD
# Collecting data for CFXBTC...
# Data saved for CFXBTC
# Collecting data for QKCETH...
# Data saved for QKCETH
# Collecting data for FIOBNB...
# Data saved for FIOBNB
# Collecting data for FIOBTC...
# Data saved for FIOBTC
# Collecting data for WINBUSD...
# Data saved for WINBUSD
# Collecting data for ERDBNB...
# Data saved for ERDBNB
# Collecting data for REIETH...
# Data saved for REIETH
# Collecting data for BLZETH...
# Data saved for BLZETH
# Collecting data for BKRWBUSD...
# Data saved for BKRWBUSD
# Collecting data for SOLETH...
# Data saved for SOLETH
# Collecting data for RUNEUSDC...
# Collecting data for VETETH...
# Data saved for VETETH
# Collecting data for BETABNB...
# Data saved for BETABNB
# Collecting data for ETHBULLBUSD...
# Data saved for ETHBULLBUSD
# Collecting data for LINKAUD...
# Data saved for LINKAUD
# Collecting data for STEEMBTC...
# Data saved for STEEMBTC
# Collecting data for ENSUSDC...
# Collecting data for BTSETH...
# Data saved for BTSETH
# Collecting data for BLURUSDC...
# Collecting data for XMRBUSD...
# Data saved for XMRBUSD
# Collecting data for SUNBTC...
# Data saved for SUNBTC
# Collecting data for HOOKBTC...
# Data saved for HOOKBTC
# Collecting data for IMXBNB...
# Data saved for IMXBNB
# Collecting data for FTMBTC...
# Data saved for FTMBTC
# Collecting data for STRAXBUSD...
# Data saved for STRAXBUSD
# Collecting data for REEFBTC...
# Data saved for REEFBTC
# Collecting data for AKROBTC...
# Data saved for AKROBTC
# Collecting data for PIVXBNB...
# Data saved for PIVXBNB
# Collecting data for COCOSBTC...
# Data saved for COCOSBTC
# Collecting data for WINEUR...
# Data saved for WINEUR
# Collecting data for WTCETH...
# Data saved for WTCETH
# Collecting data for BEARBUSD...
# Data saved for BEARBUSD
# Collecting data for MULTIBUSD...
# Data saved for MULTIBUSD
# Collecting data for ADAUSDC...
# Data saved for ADAUSDC
# Collecting data for IDBNB...
# Data saved for IDBNB
# Collecting data for LSKBNB...
# Data saved for LSKBNB
# Collecting data for FTMAUD...
# Data saved for FTMAUD
# Collecting data for TRBFDUSD...
# Collecting data for NULSBTC...
# Data saved for NULSBTC
# Collecting data for MCBUSD...
# Data saved for MCBUSD
# Collecting data for ARUSDC...
# Collecting data for DOGEAUD...
# Data saved for DOGEAUD
# Collecting data for ADABUSD...
# Data saved for ADABUSD
# Collecting data for CHRBNB...
# Data saved for CHRBNB
# Collecting data for JSTBUSD...
# Data saved for JSTBUSD
# Collecting data for GALEUR...
# Data saved for GALEUR
# Collecting data for LOKABTC...
# Data saved for LOKABTC
# Collecting data for COSBNB...
# Data saved for COSBNB
# Collecting data for CVPBUSD...
# Data saved for CVPBUSD
# Collecting data for KSMETH...
# Data saved for KSMETH
# Collecting data for FLMBNB...
# Data saved for FLMBNB
# Collecting data for 1000SATSFDUSD...
# Data saved for 1000SATSFDUSD
# Collecting data for DOGEBTC...
# Data saved for DOGEBTC
# Collecting data for ORDIUSDC...
# Data saved for ORDIUSDC
# Collecting data for BSWBUSD...
# Data saved for BSWBUSD
# Collecting data for SXPBUSD...
# Data saved for SXPBUSD
# Collecting data for VIDTBUSD...
# Data saved for VIDTBUSD
# Collecting data for PUNDIXETH...
# Data saved for PUNDIXETH
# Collecting data for JOEBTC...
# Data saved for JOEBTC
# Collecting data for RAREBTC...
# Data saved for RAREBTC
# Collecting data for LINKPAX...
# Data saved for LINKPAX
# Collecting data for TRBBUSD...
# Data saved for TRBBUSD
# Collecting data for OGNBTC...
# Data saved for OGNBTC
# Collecting data for ZENBNB...
# Data saved for ZENBNB
# Collecting data for NFPTUSD...
# Data saved for NFPTUSD
# Collecting data for AMBBTC...
# Data saved for AMBBTC
# Collecting data for APEBNB...
# Data saved for APEBNB
# Collecting data for STORJBUSD...
# Data saved for STORJBUSD
# Collecting data for TFUELBNB...
# Data saved for TFUELBNB
# Collecting data for QKCBTC...
# Data saved for QKCBTC
# Collecting data for ONGBTC...
# Data saved for ONGBTC
# Collecting data for BNBETH...
# Data saved for BNBETH
# Collecting data for FXSBUSD...
# Data saved for FXSBUSD
# Collecting data for ACMBUSD...
# Data saved for ACMBUSD
# Collecting data for BNBUST...
# Data saved for BNBUST
# Collecting data for BALBUSD...
# Data saved for BALBUSD
# Collecting data for ADXETH...
# Data saved for ADXETH
# Collecting data for ATOMBTC...
# Data saved for ATOMBTC
# Collecting data for GXSETH...
# Data saved for GXSETH
# Collecting data for BONKFDUSD...
# Data saved for BONKFDUSD
# Collecting data for TFUELTUSD...
# Data saved for TFUELTUSD
# Collecting data for LTOBUSD...
# Data saved for LTOBUSD
# Collecting data for DEXEBUSD...
# Data saved for DEXEBUSD
# Collecting data for ROSEBUSD...
# Data saved for ROSEBUSD
# Collecting data for ARPABTC...
# Data saved for ARPABTC
# Collecting data for FLUXBUSD...
# Data saved for FLUXBUSD
# Collecting data for IDEXBTC...
# Data saved for IDEXBTC
# Collecting data for SUIBTC...
# Data saved for SUIBTC
# Collecting data for DREPBNB...
# Data saved for DREPBNB
# Collecting data for XVGETH...
# Data saved for XVGETH
# Collecting data for BCHABCUSDC...
# Data saved for BCHABCUSDC
# Collecting data for SXPEUR...
# Data saved for SXPEUR
# Collecting data for PHBBTC...
# Data saved for PHBBTC
# Collecting data for LRCBNB...
# Data saved for LRCBNB
# Collecting data for RAMPBUSD...
# Data saved for RAMPBUSD
# Collecting data for PEPEUSDC...
# Collecting data for AUDBUSD...
# Data saved for AUDBUSD
# Collecting data for EPSBTC...
# Data saved for EPSBTC
# Collecting data for FDUSDBUSD...
# Data saved for FDUSDBUSD
# Collecting data for FLOKITUSD...
# Data saved for FLOKITUSD
# Collecting data for GMTBNB...
# Data saved for GMTBNB
# Collecting data for CHRETH...
# Data saved for CHRETH
# Collecting data for ETCFDUSD...
# Collecting data for AERGOBTC...
# Data saved for AERGOBTC
# Collecting data for BTSBNB...
# Data saved for BTSBNB
# Collecting data for LINABTC...
# Data saved for LINABTC
# Collecting data for SFPBUSD...
# Data saved for SFPBUSD
# Collecting data for ARBETH...
# Data saved for ARBETH
# Collecting data for TRUBTC...
# Data saved for TRUBTC
# Collecting data for AUTOBUSD...
# Data saved for AUTOBUSD
# Collecting data for TRBBTC...
# Data saved for TRBBTC
# Collecting data for YGGBTC...
# Data saved for YGGBTC
# Collecting data for CVCBTC...
# Data saved for CVCBTC
# Collecting data for BCHABCBUSD...
# Data saved for BCHABCBUSD
# Collecting data for ANKRTUSD...
# Data saved for ANKRTUSD
# Collecting data for ETHAEUR...
# Data saved for ETHAEUR
# Collecting data for PAXGBUSD...
# Data saved for PAXGBUSD
# Collecting data for KMDBUSD...
# Data saved for KMDBUSD
# Collecting data for ROSEBNB...
# Data saved for ROSEBNB
# Collecting data for BCHABCTUSD...
# Data saved for BCHABCTUSD
# Collecting data for BTCFDUSD...
# Data saved for BTCFDUSD
# Collecting data for LUNAUST...
# Data saved for LUNAUST
# Collecting data for BCHSVBTC...
# Data saved for BCHSVBTC
# Collecting data for IMXBUSD...
# Data saved for IMXBUSD
# Collecting data for NEBLBNB...
# Data saved for NEBLBNB
# Collecting data for STPTBNB...
# Data saved for STPTBNB
# Collecting data for BATTUSD...
# Data saved for BATTUSD
# Collecting data for TRXXRP...
# Data saved for TRXXRP
# Collecting data for ETHGBP...
# Data saved for ETHGBP
# Collecting data for TORNBTC...
# Data saved for TORNBTC
# Collecting data for GTCBTC...
# Data saved for GTCBTC
# Collecting data for FRONTTUSD...
# Data saved for FRONTTUSD
# Collecting data for OPUSDC...
# Data saved for OPUSDC
# Collecting data for DASHBNB...
# Data saved for DASHBNB
# Collecting data for TRIBEBTC...
# Data saved for TRIBEBTC
# Collecting data for DOTBUSD...
# Data saved for DOTBUSD
# Collecting data for KSMBNB...
# Data saved for KSMBNB
# Collecting data for CRVETH...
# Data saved for CRVETH
# Collecting data for TRXETH...
# Data saved for TRXETH
# Collecting data for LENDBUSD...
# Data saved for LENDBUSD
# Collecting data for ORNBTC...
# Data saved for ORNBTC
# Collecting data for BETHBUSD...
# Data saved for BETHBUSD
# Collecting data for FORTHBTC...
# Data saved for FORTHBTC
# Collecting data for DOTUSDC...
# Data saved for DOTUSDC
# Collecting data for FIDABUSD...
# Data saved for FIDABUSD
# Collecting data for JASMYEUR...
# Data saved for JASMYEUR
# Collecting data for MANAETH...
# Data saved for MANAETH
# Collecting data for CKBUSDC...
# Collecting data for NPXSETH...
# Data saved for NPXSETH
# Collecting data for TOMOBNB...
# Data saved for TOMOBNB
# Collecting data for STRATETH...
# Data saved for STRATETH
# Collecting data for BTTUSDC...
# Data saved for BTTUSDC
# Collecting data for SUSDETH...
# Data saved for SUSDETH
# Collecting data for ERNBUSD...
# Data saved for ERNBUSD
# Collecting data for PEPEEUR...
# Collecting data for EGLDETH...
# Data saved for EGLDETH
# Collecting data for USDSTUSD...
# Data saved for USDSTUSD
# Collecting data for POLYXBUSD...
# Data saved for POLYXBUSD
# Collecting data for RUNEBNB...
# Data saved for RUNEBNB
# Collecting data for CAKEBTC...
# Data saved for CAKEBTC
# Collecting data for RADBUSD...
# Data saved for RADBUSD
# Collecting data for BTTBTC...
# Data saved for BTTBTC
# Collecting data for USTBTC...
# Data saved for USTBTC
# Collecting data for DENTETH...
# Data saved for DENTETH
# Collecting data for KMDBTC...
# Data saved for KMDBTC
# Collecting data for YFIIBUSD...
# Data saved for YFIIBUSD
# Collecting data for SHIBGBP...
# Data saved for SHIBGBP
# Collecting data for REPBUSD...
# Data saved for REPBUSD
# Collecting data for OGNBUSD...
# Data saved for OGNBUSD
# Collecting data for WOOBNB...
# Data saved for WOOBNB
# Collecting data for WANBTC...
# Data saved for WANBTC
# Collecting data for NULSETH...
# Data saved for NULSETH
# Collecting data for LDOTUSD...
# Data saved for LDOTUSD
# Collecting data for GALABTC...
# Data saved for GALABTC
# Collecting data for JASMYETH...
# Data saved for JASMYETH
# Collecting data for ALPHABTC...
# Data saved for ALPHABTC
# Collecting data for FLOKIUSDC...
# Collecting data for DCRBNB...
# Data saved for DCRBNB
# Collecting data for XLMBTC...
# Data saved for XLMBTC
# Collecting data for MBOXBNB...
# Data saved for MBOXBNB
# Collecting data for ONEETH...
# Data saved for ONEETH
# Collecting data for BTCEUR...
# Data saved for BTCEUR
# Collecting data for LAZIOBUSD...
# Data saved for LAZIOBUSD
# Collecting data for FIOBUSD...
# Data saved for FIOBUSD
# Collecting data for HIGHBTC...
# Data saved for HIGHBTC
# Collecting data for ETCBNB...
# Data saved for ETCBNB
# Collecting data for MAVBTC...
# Data saved for MAVBTC
# Collecting data for WNXMBTC...
# Data saved for WNXMBTC
# Collecting data for PONDBUSD...
# Data saved for PONDBUSD
# Collecting data for HOOKBNB...
# Data saved for HOOKBNB
# Collecting data for UNIFDUSD...
# Collecting data for LINKETH...
# Data saved for LINKETH
# Collecting data for BNBFDUSD...
# Data saved for BNBFDUSD
# Collecting data for ALGOBNB...
# Data saved for ALGOBNB
# Collecting data for PERLBTC...
# Data saved for PERLBTC
# Collecting data for BTCSTBTC...
# Data saved for BTCSTBTC
# Collecting data for GTCBUSD...
# Data saved for GTCBUSD
# Collecting data for STGBUSD...
# Data saved for STGBUSD
# Collecting data for SHIBUSDC...
# Collecting data for PONDBTC...
# Data saved for PONDBTC
# Collecting data for CTKBTC...
# Data saved for CTKBTC
# Collecting data for ANCBTC...
# Data saved for ANCBTC
# Collecting data for NEOTUSD...
# Data saved for NEOTUSD
# Collecting data for STRAXBTC...
# Data saved for STRAXBTC
# Collecting data for BNBUSDS...
# Data saved for BNBUSDS
# Collecting data for APTETH...
# Data saved for APTETH
# Collecting data for FUNBTC...
# Data saved for FUNBTC
# Collecting data for XZCXRP...
# Data saved for XZCXRP
# Collecting data for FILUSDC...
# Collecting data for ONEPAX...
# Data saved for ONEPAX
# Collecting data for VITEBUSD...
# Data saved for VITEBUSD
# Collecting data for BAKEBNB...
# Data saved for BAKEBNB
# Collecting data for FILBTC...
# Data saved for FILBTC
# Collecting data for CRVBNB...
# Data saved for CRVBNB
# Collecting data for XTZETH...
# Data saved for XTZETH
# Collecting data for GALABUSD...
# Data saved for GALABUSD
# Collecting data for ETCTUSD...
# Data saved for ETCTUSD
# Collecting data for GNOBTC...
# Data saved for GNOBTC
# Collecting data for ETCUSDC...
# Data saved for ETCUSDC
# Collecting data for LRCETH...
# Data saved for LRCETH
# Collecting data for PAXTUSD...
# Data saved for PAXTUSD
# Collecting data for GMTBUSD...
# Data saved for GMTBUSD
# Collecting data for CITYBUSD...
# Data saved for CITYBUSD
# Collecting data for BTSBUSD...
# Data saved for BTSBUSD
# Collecting data for XRPEUR...
# Data saved for XRPEUR
# Collecting data for LTCBUSD...
# Data saved for LTCBUSD
# Collecting data for DREPBTC...
# Data saved for DREPBTC
# Collecting data for CKBBTC...
# Data saved for CKBBTC
# Collecting data for RAREUSDC...
# Collecting data for ONTBNB...
# Data saved for ONTBNB
# Collecting data for APEETH...
# Data saved for APEETH
# Collecting data for POLYBUSD...
# Data saved for POLYBUSD
# Collecting data for FORBTC...
# Data saved for FORBTC
# Collecting data for RSRBNB...
# Data saved for RSRBNB
# Collecting data for BTTCUSDC...
# Data saved for BTTCUSDC
# Collecting data for EOSAUD...
# Data saved for EOSAUD
# Collecting data for NFPFDUSD...
# Data saved for NFPFDUSD
# Collecting data for PEOPLEUSDC...
# Collecting data for ACABTC...
# Data saved for ACABTC
# Collecting data for BNXBUSD...
# Data saved for BNXBUSD
# Collecting data for LRCBUSD...
# Data saved for LRCBUSD
# Collecting data for GLMRBNB...
# Data saved for GLMRBNB
# Collecting data for VOXELETH...
# Data saved for VOXELETH
# Collecting data for BICOBTC...
# Data saved for BICOBTC
# Collecting data for ATOMFDUSD...
# Data saved for ATOMFDUSD
# Collecting data for KLAYBTC...
# Data saved for KLAYBTC
# Collecting data for LENDBTC...
# Data saved for LENDBTC
# Collecting data for API3BTC...
# Data saved for API3BTC
# Collecting data for COMPBTC...
# Data saved for COMPBTC
# Collecting data for SPELLBTC...
# Data saved for SPELLBTC
# Collecting data for NEOBTC...
# Data saved for NEOBTC
# Collecting data for SLPBUSD...
# Data saved for SLPBUSD
# Collecting data for QIBUSD...
# Data saved for QIBUSD
# Collecting data for MASKBNB...
# Data saved for MASKBNB
# Collecting data for FETBUSD...
# Data saved for FETBUSD
# Collecting data for SEIBTC...
# Data saved for SEIBTC
# Collecting data for XRPPAX...
# Data saved for XRPPAX
# Collecting data for ASRBTC...
# Data saved for ASRBTC
# Collecting data for AGLDBTC...
# Data saved for AGLDBTC
# Collecting data for MATICBNB...
# Data saved for MATICBNB
# Collecting data for KDABUSD...
# Data saved for KDABUSD
# Collecting data for CYBERBNB...
# Data saved for CYBERBNB
# Collecting data for PROSBUSD...
# Data saved for PROSBUSD
# Collecting data for XRPBNB...
# Data saved for XRPBNB
# Collecting data for POWRBNB...
# Data saved for POWRBNB
# Collecting data for POLSBNB...
# Data saved for POLSBNB
# Collecting data for UNIAUD...
# Data saved for UNIAUD
# Collecting data for BNBPAX...
# Data saved for BNBPAX
# Collecting data for WINUSDC...
# Data saved for WINUSDC
# Collecting data for LUNAAUD...
# Data saved for LUNAAUD
# Collecting data for CELRBUSD...
# Data saved for CELRBUSD
# Collecting data for SANTOSBUSD...
# Data saved for SANTOSBUSD
# Collecting data for AVAXAUD...
# Data saved for AVAXAUD
# Collecting data for CVCBNB...
# Data saved for CVCBNB
# Collecting data for GMTETH...
# Data saved for GMTETH
# Collecting data for VGXBTC...
# Data saved for VGXBTC
# Collecting data for WTCBTC...
# Data saved for WTCBTC
# Collecting data for SLPETH...
# Data saved for SLPETH
# Collecting data for REPBNB...
# Data saved for REPBNB
# Collecting data for HARDBTC...
# Data saved for HARDBTC
# Collecting data for WAXPBUSD...
# Data saved for WAXPBUSD
# Collecting data for WRXBNB...
# Data saved for WRXBNB
# Collecting data for EDUBNB...
# Data saved for EDUBNB
# Collecting data for POLYBNB...
# Data saved for POLYBNB
# Collecting data for TLMBUSD...
# Data saved for TLMBUSD
# Collecting data for HFTBTC...
# Data saved for HFTBTC
# Collecting data for BELBNB...
# Data saved for BELBNB
# Collecting data for CYBERTUSD...
# Data saved for CYBERTUSD
# Collecting data for EDUTUSD...
# Data saved for EDUTUSD
# Collecting data for AERGOBUSD...
# Data saved for AERGOBUSD
# Collecting data for VICBTC...
# Data saved for VICBTC
# Collecting data for MTLBUSD...
# Data saved for MTLBUSD
# Collecting data for ORNBUSD...
# Data saved for ORNBUSD
# Collecting data for BAKEBTC...
# Data saved for BAKEBTC
# Collecting data for PAXBUSD...
# Data saved for PAXBUSD
# Collecting data for 1INCHBTC...
# Data saved for 1INCHBTC
# Collecting data for AVAXETH...
# Data saved for AVAXETH
# Collecting data for IOSTBTC...
# Data saved for IOSTBTC
# Collecting data for IRISBUSD...
# Data saved for IRISBUSD
# Collecting data for MIRBUSD...
# Data saved for MIRBUSD
# Collecting data for MDXBTC...
# Data saved for MDXBTC
# Collecting data for LINABUSD...
# Data saved for LINABUSD
# Collecting data for SSVETH...
# Data saved for SSVETH
# Collecting data for BTCPAX...
# Data saved for BTCPAX
# Collecting data for BCHBTC...
# Data saved for BCHBTC
# Collecting data for SHIBBUSD...
# Data saved for SHIBBUSD
# Collecting data for TROYBUSD...
# Data saved for TROYBUSD
# Collecting data for HOTBTC...
# Data saved for HOTBTC
# Collecting data for BNBUSDP...
# Data saved for BNBUSDP
# Collecting data for ZRXBTC...
# Data saved for ZRXBTC
# Collecting data for FILBNB...
# Data saved for FILBNB
# Collecting data for LEVERBUSD...
# Data saved for LEVERBUSD
# Collecting data for TROYBTC...
# Data saved for TROYBTC
# Collecting data for HIGHBNB...
# Data saved for HIGHBNB
# Collecting data for ETCGBP...
# Data saved for ETCGBP
# Collecting data for FETBTC...
# Data saved for FETBTC
# Collecting data for XRPFDUSD...
# Data saved for XRPFDUSD
# Collecting data for MDXBNB...
# Data saved for MDXBNB
# Collecting data for WBTCBUSD...
# Data saved for WBTCBUSD
# Collecting data for MFTETH...
# Data saved for MFTETH
# Collecting data for ACEBTC...
# Data saved for ACEBTC
# Collecting data for ETHUSDP...
# Data saved for ETHUSDP
# Collecting data for CTKBUSD...
# Data saved for CTKBUSD
# Collecting data for BTGBUSD...
# Data saved for BTGBUSD
# Collecting data for SEITUSD...
# Data saved for SEITUSD
# Collecting data for CELRETH...
# Data saved for CELRETH
# Collecting data for DOGETUSD...
# Data saved for DOGETUSD
# Collecting data for OSMOBUSD...
# Data saved for OSMOBUSD
# Collecting data for NEOUSDC...
# Data saved for NEOUSDC
# Collecting data for FILETH...
# Data saved for FILETH
# Collecting data for KEEPBUSD...
# Data saved for KEEPBUSD
# Collecting data for RENBUSD...
# Data saved for RENBUSD
# Collecting data for JSTBTC...
# Data saved for JSTBTC
# Collecting data for MINABUSD...
# Data saved for MINABUSD
# Collecting data for TROYBNB...
# Data saved for TROYBNB
# Collecting data for SUSHIBTC...
# Data saved for SUSHIBTC
# Collecting data for ERNBNB...
# Data saved for ERNBNB
# Collecting data for FLUXBTC...
# Data saved for FLUXBTC
# Collecting data for WOOBTC...
# Data saved for WOOBTC
# Collecting data for SUPERBUSD...
# Data saved for SUPERBUSD
# Collecting data for RPLBTC...
# Data saved for RPLBTC
# Collecting data for WLDBTC...
# Data saved for WLDBTC
# Collecting data for YGGBNB...
# Data saved for YGGBNB
# Collecting data for SEIUSDC...
# Collecting data for INJETH...
# Data saved for INJETH
# Collecting data for ERDPAX...
# Data saved for ERDPAX
# Collecting data for SSVBUSD...
# Data saved for SSVBUSD
# Collecting data for DAIBUSD...
# Data saved for DAIBUSD
# Collecting data for AVAXGBP...
# Data saved for AVAXGBP
# Collecting data for MTLBTC...
# Data saved for MTLBTC
# Collecting data for TUSDETH...
# Data saved for TUSDETH
# Collecting data for VETBTC...
# Data saved for VETBTC
# Collecting data for EGLDBNB...
# Data saved for EGLDBNB
# Collecting data for AGIXBTC...
# Data saved for AGIXBTC
# Collecting data for CRVBTC...
# Data saved for CRVBTC
# Collecting data for WINBTC...
# Data saved for WINBTC
# Collecting data for ORDIBTC...
# Data saved for ORDIBTC
# Collecting data for FIDABNB...
# Data saved for FIDABNB
# Collecting data for LINKBKRW...
# Data saved for LINKBKRW
# Collecting data for TRXBUSD...
# Data saved for TRXBUSD
# Collecting data for APTUSDC...
# Collecting data for TORNBNB...
# Data saved for TORNBNB
# Collecting data for BSWBNB...
# Data saved for BSWBNB
# Collecting data for EOSBTC...
# Data saved for EOSBTC
# Collecting data for FTMTUSD...
# Data saved for FTMTUSD
# Collecting data for LTOBNB...
# Data saved for LTOBNB
# Collecting data for GALETH...
# Data saved for GALETH
# Collecting data for XRPBULLBUSD...
# Data saved for XRPBULLBUSD
# Collecting data for LQTYBTC...
# Data saved for LQTYBTC
# Collecting data for INJUSDC...
# Data saved for INJUSDC
# Collecting data for KSMBTC...
# Data saved for KSMBTC
# Collecting data for WAVESTUSD...
# Data saved for WAVESTUSD
# Collecting data for PROSETH...
# Data saved for PROSETH
# Collecting data for SUNBUSD...
# Data saved for SUNBUSD
# Collecting data for STORMETH...
# Data saved for STORMETH
# Collecting data for SCRTBUSD...
# Data saved for SCRTBUSD
# Collecting data for XRPGBP...
# Data saved for XRPGBP
# Collecting data for USDPBUSD...
# Data saved for USDPBUSD
# Collecting data for AMPBNB...
# Data saved for AMPBNB
# Collecting data for SSVTUSD...
# Data saved for SSVTUSD
# Collecting data for RAMPBTC...
# Data saved for RAMPBTC
# Collecting data for LINKBUSD...
# Data saved for LINKBUSD
# Collecting data for NEOBUSD...
# Data saved for NEOBUSD
# Collecting data for VOXELBTC...
# Data saved for VOXELBTC
# Collecting data for XEMBNB...
# Data saved for XEMBNB
# Collecting data for CHZBUSD...
# Data saved for CHZBUSD
# Collecting data for ALCXBUSD...
# Data saved for ALCXBUSD
# Collecting data for DEGOBUSD...
# Data saved for DEGOBUSD
# Collecting data for TIATUSD...
# Data saved for TIATUSD
# Collecting data for APEBUSD...
# Data saved for APEBUSD
# Collecting data for SANDFDUSD...
# Data saved for SANDFDUSD
# Collecting data for XLMBUSD...
# Data saved for XLMBUSD
# Collecting data for NEARETH...
# Data saved for NEARETH
# Collecting data for PROMBNB...
# Data saved for PROMBNB
# Collecting data for AAVEBNB...
# Data saved for AAVEBNB
# Collecting data for 1000SATSUSDC...
# Collecting data for APEAUD...
# Data saved for APEAUD
# Collecting data for MAGICBUSD...
# Data saved for MAGICBUSD
# Collecting data for STXUSDC...
# Collecting data for ATOMEUR...
# Data saved for ATOMEUR
# Collecting data for BTGBTC...
# Data saved for BTGBTC
# Collecting data for SUPERFDUSD...
# Data saved for SUPERFDUSD
# Collecting data for DASHETH...
# Data saved for DASHETH
# Collecting data for EOSBULLBUSD...
# Data saved for EOSBULLBUSD
# Collecting data for GALAETH...
# Data saved for GALAETH
# Collecting data for ICPBUSD...
# Data saved for ICPBUSD
# Collecting data for NANOBTC...
# Data saved for NANOBTC
# Collecting data for NANOBUSD...
# Data saved for NANOBUSD
# Collecting data for ILVBUSD...
# Data saved for ILVBUSD
# Collecting data for WINGBTC...
# Data saved for WINGBTC
# Collecting data for LINKBNB...
# Data saved for LINKBNB
# Collecting data for UNFIBUSD...
# Data saved for UNFIBUSD
# Collecting data for FARMBUSD...
# Data saved for FARMBUSD
# Collecting data for AVABUSD...
# Data saved for AVABUSD
# Collecting data for ELFBUSD...
# Data saved for ELFBUSD
# Collecting data for BCHTUSD...
# Data saved for BCHTUSD
# Collecting data for STRATBUSD...
# Data saved for STRATBUSD
# Collecting data for FETFDUSD...
# Data saved for FETFDUSD
# Collecting data for HBARBTC...
# Data saved for HBARBTC
# Collecting data for ILVBTC...
# Data saved for ILVBTC
# Collecting data for SOLEUR...
# Data saved for SOLEUR
# Collecting data for NEARBUSD...
# Data saved for NEARBUSD
# Collecting data for VANRYBTC...
# Data saved for VANRYBTC
# Collecting data for ICPBNB...
# Data saved for ICPBNB
# Collecting data for ANKRBNB...
# Data saved for ANKRBNB
# Collecting data for SOLTUSD...
# Data saved for SOLTUSD
# Collecting data for SCETH...
# Data saved for SCETH
# Collecting data for WANBNB...
# Data saved for WANBNB
# Collecting data for WINGBUSD...
# Data saved for WINGBUSD
# Collecting data for AUDUSDC...
# Data saved for AUDUSDC
# Collecting data for ANYBTC...
# Data saved for ANYBTC
# Collecting data for SYNBTC...
# Data saved for SYNBTC
# Collecting data for ENSBUSD...
# Data saved for ENSBUSD
# Collecting data for AGLDBNB...
# Data saved for AGLDBNB
# Collecting data for PUNDIXBUSD...
# Data saved for PUNDIXBUSD
# Collecting data for WANETH...
# Data saved for WANETH
# Collecting data for MANABUSD...
# Data saved for MANABUSD
# Collecting data for DARBNB...
# Data saved for DARBNB
# Collecting data for BICOBUSD...
# Data saved for BICOBUSD
# Collecting data for WBTCETH...
# Data saved for WBTCETH
# Collecting data for BCHSVTUSD...
# Data saved for BCHSVTUSD
# Collecting data for SKLBUSD...
# Data saved for SKLBUSD
# Collecting data for INJTUSD...
# Data saved for INJTUSD
# Collecting data for DNTBUSD...
# Data saved for DNTBUSD
# Collecting data for STXBUSD...
# Data saved for STXBUSD
# Collecting data for DIABTC...
# Data saved for DIABTC
# Collecting data for CELRBTC...
# Data saved for CELRBTC
# Collecting data for CVCBUSD...
# Data saved for CVCBUSD
# Collecting data for AVAXBNB...
# Data saved for AVAXBNB
# Collecting data for ADAAUD...
# Data saved for ADAAUD
# Collecting data for OPBTC...
# Data saved for OPBTC
# Collecting data for FTMBUSD...
# Data saved for FTMBUSD
# Collecting data for RADBTC...
# Data saved for RADBTC
# Collecting data for ZENBUSD...
# Data saved for ZENBUSD
# Collecting data for BELBTC...
# Data saved for BELBTC
# Collecting data for RIFBTC...
# Data saved for RIFBTC
# Collecting data for ICPUSDC...
# Collecting data for HIFIETH...
# Data saved for HIFIETH
# Collecting data for RAYFDUSD...
# Collecting data for ALPHABNB...
# Data saved for ALPHABNB
# Collecting data for BNBUSDC...
# Data saved for BNBUSDC
# Collecting data for RNDRBTC...
# Data saved for RNDRBTC
# Collecting data for FTMEUR...
# Data saved for FTMEUR
# Collecting data for SNTETH...
# Data saved for SNTETH
# Collecting data for AMPBTC...
# Data saved for AMPBTC
# Collecting data for XRPETH...
# Data saved for XRPETH
# Collecting data for GXSBTC...
# Data saved for GXSBTC
# Collecting data for SYSBNB...
# Data saved for SYSBNB
# Collecting data for ZECBTC...
# Data saved for ZECBTC
# Collecting data for FARMBNB...
# Data saved for FARMBNB
# Collecting data for VIBETH...
# Data saved for VIBETH
# Collecting data for QUICKTUSD...
# Data saved for QUICKTUSD
# Collecting data for BONDETH...
# Data saved for BONDETH
# Collecting data for IQBUSD...
# Data saved for IQBUSD
# Collecting data for APTBTC...
# Data saved for APTBTC
# Collecting data for MKRBNB...
# Data saved for MKRBNB
# Collecting data for TCTBTC...
# Data saved for TCTBTC
# Collecting data for QUICKBUSD...
# Data saved for QUICKBUSD
# Collecting data for QNTBUSD...
# Data saved for QNTBUSD
# Collecting data for WAXPBNB...
# Data saved for WAXPBNB
# Collecting data for BCHSVPAX...
# Data saved for BCHSVPAX
# Collecting data for THETAETH...
# Data saved for THETAETH
# Collecting data for IDEXBNB...
# Data saved for IDEXBNB
# Collecting data for ETHPAX...
# Data saved for ETHPAX
# Collecting data for OGBTC...
# Data saved for OGBTC
# Collecting data for ONEBTC...
# Data saved for ONEBTC
# Collecting data for DOTBNB...
# Data saved for DOTBNB
# Collecting data for GALAFDUSD...
# Data saved for GALAFDUSD
# Collecting data for VOXELBUSD...
# Data saved for VOXELBUSD
# Collecting data for RSRBTC...
# Data saved for RSRBTC
# Collecting data for STORMBTC...
# Data saved for STORMBTC
# Collecting data for CREAMBNB...
# Data saved for CREAMBNB
# Collecting data for ASTETH...
# Data saved for ASTETH
# Collecting data for XLMUSDC...
# Data saved for XLMUSDC
# Collecting data for BATBUSD...
# Data saved for BATBUSD
# Collecting data for API3BUSD...
# Data saved for API3BUSD
# Collecting data for XMRBTC...
# Data saved for XMRBTC
# Collecting data for PROMBTC...
# Data saved for PROMBTC
# Collecting data for IQBNB...
# Data saved for IQBNB
# Collecting data for RUNEEUR...
# Data saved for RUNEEUR
# Collecting data for UNFIBTC...
# Data saved for UNFIBTC
# Collecting data for TRXBNB...
# Data saved for TRXBNB
# Collecting data for MATICGBP...
# Data saved for MATICGBP
# Collecting data for BTTPAX...
# Data saved for BTTPAX
# Collecting data for ATABNB...
# Data saved for ATABNB
# Collecting data for C98BUSD...
# Data saved for C98BUSD
# Collecting data for TUSDBNB...
# Data saved for TUSDBNB
# Collecting data for ERDBTC...
# Data saved for ERDBTC
# Collecting data for POWRETH...
# Data saved for POWRETH
# Collecting data for DOGEGBP...
# Data saved for DOGEGBP
# Collecting data for GTCBNB...
# Data saved for GTCBNB
# Collecting data for TRXBTC...
# Data saved for TRXBTC
# Collecting data for DAREUR...
# Data saved for DAREUR
# Collecting data for ROSEBTC...
# Data saved for ROSEBTC
# Collecting data for LOOMBTC...
# Data saved for LOOMBTC
# Collecting data for SPELLBUSD...
# Data saved for SPELLBUSD
# Collecting data for USTCFDUSD...
# Data saved for USTCFDUSD
# Collecting data for POLYBTC...
# Data saved for POLYBTC
# Collecting data for BURGERBUSD...
# Data saved for BURGERBUSD
# Collecting data for GRTBUSD...
# Data saved for GRTBUSD
# Collecting data for ADABTC...
# Data saved for ADABTC
# Collecting data for OPBNB...
# Data saved for OPBNB
# Collecting data for ARBTC...
# Data saved for ARBTC
# Collecting data for WAVESBTC...
# Data saved for WAVESBTC
# Collecting data for NPXSUSDC...
# Data saved for NPXSUSDC
# Collecting data for DASHBUSD...
# Data saved for DASHBUSD
# Collecting data for ETHUSDC...
# Data saved for ETHUSDC
# Collecting data for PHABUSD...
# Data saved for PHABUSD
# Collecting data for XRPBUSD...
# Data saved for XRPBUSD
# Collecting data for PORTOBTC...
# Data saved for PORTOBTC
# Collecting data for VGXETH...
# Data saved for VGXETH
# Collecting data for TCTBNB...
# Data saved for TCTBNB
# Collecting data for TRXUSDC...
# Data saved for TRXUSDC
# Collecting data for DYDXFDUSD...
# ...
# Data saved for PHBUSDC
# Collecting data for GNSBTC...
# Data saved for GNSBTC
# Collecting data for C98BTC...
# Data saved for C98BTC
# Collecting data for ARBUSDC...
# Data saved for ARBUSDC
# Collecting data for ANCBNB...
# Data saved for ANCBNB
# Collecting data for AUCTIONBUSD...
# Data saved for AUCTIONBUSD
# Collecting data for DYDXBTC...
# Data saved for DYDXBTC
# Collecting data for XVGTUSD...
# Data saved for XVGTUSD
# Collecting data for ADXBTC...
# Data saved for ADXBTC
# Collecting data for RAREBNB...
# Data saved for RAREBNB
# Collecting data for BTTTUSD...
# Data saved for BTTTUSD
# Collecting data for HIVEBUSD...
# Data saved for HIVEBUSD
# Collecting data for WOOBUSD...
# Data saved for WOOBUSD
# Collecting data for FTMBNB...
# Data saved for FTMBNB
# Collecting data for OGNBNB...
# Data saved for OGNBNB
# Collecting data for RADBNB...
# Data saved for RADBNB
# Collecting data for TKOBTC...
# Data saved for TKOBTC
# Collecting data for ONTUSDC...
# Data saved for ONTUSDC
# Collecting data for FIROBUSD...
# Data saved for FIROBUSD
# Collecting data for DOGEFDUSD...
# Data saved for DOGEFDUSD
# Collecting data for GALABNB...
# Data saved for GALABNB
# Collecting data for EPSBUSD...
# Data saved for EPSBUSD
# Collecting data for RAYBNB...
# Data saved for RAYBNB
# Collecting data for AGIXFDUSD...
# Collecting data for LOKABUSD...
# Data saved for LOKABUSD
# Collecting data for OPEUR...
# Data saved for OPEUR
# Collecting data for OSMOBTC...
# Data saved for OSMOBTC
# Collecting data for TKOBUSD...
# Data saved for TKOBUSD
# Collecting data for DOTTUSD...
# Data saved for DOTTUSD
# Collecting data for DEXEETH...
# Data saved for DEXEETH
# Collecting data for BZRXBTC...
# Data saved for BZRXBTC
# Collecting data for ASTBTC...
# Data saved for ASTBTC
# Collecting data for ELFBTC...
# Data saved for ELFBTC
# Collecting data for NEXOBUSD...
# Data saved for NEXOBUSD
# Collecting data for BTCUSDS...
# Data saved for BTCUSDS
# Collecting data for OCEANBTC...
# Data saved for OCEANBTC
# Collecting data for STEEMBNB...
# Data saved for STEEMBNB
# Collecting data for DOTAUD...
# Data saved for DOTAUD
# Collecting data for ARKBUSD...
# Data saved for ARKBUSD
# Collecting data for MIRBTC...
# Data saved for MIRBTC
# Collecting data for GMXBUSD...
# Data saved for GMXBUSD
# Collecting data for CAKEBUSD...
# Data saved for CAKEBUSD
# Collecting data for TFUELBTC...
# Data saved for TFUELBTC
# Collecting data for SANDBTC...
# Data saved for SANDBTC
# Collecting data for USTCBUSD...
# Data saved for USTCBUSD
# Collecting data for MTLETH...
# Data saved for MTLETH
# Collecting data for OAXBTC...
# Data saved for OAXBTC
# Collecting data for ZRXBNB...
# Data saved for ZRXBNB
# Collecting data for AMBETH...
# Data saved for AMBETH
# Collecting data for PEOPLEFDUSD...
# Collecting data for FLOWBNB...
# Data saved for FLOWBNB
# Collecting data for STRAXETH...
# Data saved for STRAXETH
# Collecting data for ETHBUSD...
# Data saved for ETHBUSD
# Collecting data for RSRBUSD...
# Data saved for RSRBUSD
# Collecting data for LOOMETH...
# Data saved for LOOMETH
# Collecting data for AKROBUSD...
# Data saved for AKROBUSD
# Collecting data for PERLUSDC...
# Data saved for PERLUSDC
# Collecting data for CFXUSDC...
# Collecting data for CREAMBUSD...
# Data saved for CREAMBUSD
# Collecting data for IOTAFDUSD...
# Data saved for IOTAFDUSD
# Collecting data for KP3RBUSD...
# Data saved for KP3RBUSD
# Collecting data for SXPAUD...
# Data saved for SXPAUD
# Collecting data for SNXBNB...
# Data saved for SNXBNB
# Collecting data for GRTBTC...
# Data saved for GRTBTC
# Collecting data for MOVRBTC...
# Data saved for MOVRBTC
# Collecting data for DOTBKRW...
# Data saved for DOTBKRW
# Collecting data for EOSBUSD...
# Data saved for EOSBUSD
# Collecting data for MOVRBUSD...
# Data saved for MOVRBUSD
# Collecting data for USDCTUSD...
# Data saved for USDCTUSD
# Collecting data for TUSDBTC...
# Data saved for TUSDBTC
# Collecting data for MATICUSDC...
# Data saved for MATICUSDC
# Collecting data for LITETH...
# Data saved for LITETH
# Collecting data for BEAMBTC...
# Data saved for BEAMBTC
# Collecting data for IOSTBUSD...
# Data saved for IOSTBUSD
# Collecting data for CHZBNB...
# Data saved for CHZBNB
# Collecting data for QTUMBNB...
# Data saved for QTUMBNB
# Collecting data for MCOBTC...
# Data saved for MCOBTC
# Collecting data for MINABNB...
# Data saved for MINABNB
# Collecting data for LPTBTC...
# Data saved for LPTBTC
# Collecting data for PHABTC...
# Data saved for PHABTC
# Collecting data for FORBUSD...
# Data saved for FORBUSD
# Collecting data for EOSPAX...
# Data saved for EOSPAX
# Collecting data for PORTOBUSD...
# Data saved for PORTOBUSD
# Collecting data for QTUMETH...
# Data saved for QTUMETH
# Collecting data for COMPBUSD...
# Data saved for COMPBUSD
# Collecting data for MBOXBTC...
# Data saved for MBOXBTC
# Collecting data for NUBTC...
# Data saved for NUBTC
# Collecting data for SUIEUR...
# Data saved for SUIEUR
# Collecting data for OPBUSD...
# Data saved for OPBUSD
# Collecting data for ARBUSD...
# Data saved for ARBUSD
# Collecting data for IMXBTC...
# Data saved for IMXBTC
# Collecting data for ARKMBNB...
# Data saved for ARKMBNB
# Collecting data for ADAEUR...
# Data saved for ADAEUR
# Collecting data for BCHSVUSDC...
# Data saved for BCHSVUSDC
# Collecting data for KNCBUSD...
# Data saved for KNCBUSD
# Collecting data for SKLBTC...
# Data saved for SKLBTC
# Collecting data for GTOBUSD...
# Data saved for GTOBUSD
# Collecting data for ANTBNB...
# Data saved for ANTBNB
# Collecting data for ICPETH...
# Data saved for ICPETH
# Collecting data for MANABTC...
# Data saved for MANABTC
# Collecting data for GASBUSD...
# Data saved for GASBUSD
# Collecting data for NEOPAX...
# Data saved for NEOPAX
# Collecting data for ZECUSDC...
# Data saved for ZECUSDC
# Collecting data for PLABUSD...
# Data saved for PLABUSD
# Collecting data for VIBBTC...
# Data saved for VIBBTC
# Collecting data for KNCBNB...
# Data saved for KNCBNB
# Collecting data for SNXBUSD...
# Data saved for SNXBUSD
# Collecting data for MULTIBTC...
# Data saved for MULTIBTC
# Collecting data for CAKEBNB...
# Data saved for CAKEBNB
# Collecting data for ALGOUSDC...
# Data saved for ALGOUSDC
# Collecting data for USDSPAX...
# Data saved for USDSPAX
# Collecting data for ZRXBUSD...
# Data saved for ZRXBUSD
# Collecting data for ENJGBP...
# Data saved for ENJGBP
# Collecting data for BONDBNB...
# Data saved for BONDBNB
# Collecting data for ADAPAX...
# Data saved for ADAPAX
# Collecting data for LSKETH...
# Data saved for LSKETH
# Collecting data for BTCUST...
# Data saved for BTCUST
# Collecting data for PNTBTC...
# Data saved for PNTBTC
# Collecting data for BCHEUR...
# Data saved for BCHEUR
# Collecting data for UMABTC...
# Data saved for UMABTC
# Collecting data for ASTRBTC...
# Data saved for ASTRBTC
# Collecting data for CYBERETH...
# Data saved for CYBERETH
# Collecting data for GALAEUR...
# Data saved for GALAEUR
# Collecting data for XEMBTC...
# Data saved for XEMBTC
# Collecting data for BNBDAI...
# Data saved for BNBDAI
# Collecting data for ARBFDUSD...
# Data saved for ARBFDUSD
# Collecting data for BTCBKRW...
# Data saved for BTCBKRW
# Collecting data for SRMBNB...
# Data saved for SRMBNB
# Collecting data for ZECBUSD...
# Data saved for ZECBUSD
# Collecting data for WNXMBNB...
# Data saved for WNXMBNB
# Collecting data for LITBUSD...
# Data saved for LITBUSD
# Collecting data for SOLBUSD...
# Data saved for SOLBUSD
# Collecting data for DYDXETH...
# Data saved for DYDXETH
# Collecting data for XZCBNB...
# Data saved for XZCBNB
# Collecting data for NFPBNB...
# Data saved for NFPBNB
# Collecting data for GLMBTC...
# Data saved for GLMBTC
# Collecting data for BTCTUSD...
# Data saved for BTCTUSD
# Collecting data for BCHBNB...
# Data saved for BCHBNB
# Collecting data for IRISBNB...
# Data saved for IRISBNB
# Collecting data for PEOPLEBUSD...
# Data saved for PEOPLEBUSD
# Collecting data for RGTBNB...
# Data saved for RGTBNB
# Collecting data for POLSBUSD...
# Data saved for POLSBUSD
# Collecting data for KAVAETH...
# Data saved for KAVAETH
# Collecting data for DOGEUSDC...
# Data saved for DOGEUSDC
# Collecting data for MAGICFDUSD...
# Collecting data for MLNBNB...
# Data saved for MLNBNB
# Collecting data for DAIBNB...
# Data saved for DAIBNB
# Collecting data for ENJETH...
# Data saved for ENJETH
# Collecting data for PAXGBNB...
# Data saved for PAXGBNB
# Collecting data for VTHOBUSD...
# Data saved for VTHOBUSD
# Collecting data for HIVEBTC...
# Data saved for HIVEBTC
# Collecting data for ARKMFDUSD...
# Collecting data for DOCKBUSD...
# Data saved for DOCKBUSD
# Collecting data for LTCEUR...
# Data saved for LTCEUR
# Collecting data for ARBEUR...
# Data saved for ARBEUR
# Collecting data for CHZBTC...
# Data saved for CHZBTC
# Collecting data for TFUELPAX...
# Data saved for TFUELPAX
# Collecting data for XVGBTC...
# Data saved for XVGBTC
# Collecting data for COMBOBNB...
# Data saved for COMBOBNB
# Collecting data for ALPHABUSD...
# Data saved for ALPHABUSD
# Collecting data for ADAFDUSD...
# Data saved for ADAFDUSD
# Collecting data for DOGEBNB...
# Data saved for DOGEBNB
# Collecting data for ARPAETH...
# Data saved for ARPAETH
# Collecting data for OGBUSD...
# Data saved for OGBUSD
# Collecting data for ARDRBTC...
# Data saved for ARDRBTC
# Collecting data for SXPBNB...
# Data saved for SXPBNB
# Collecting data for EGLDBTC...
# Data saved for EGLDBTC
# Collecting data for SUIFDUSD...
# Data saved for SUIFDUSD
# Collecting data for ALPINEBTC...
# Data saved for ALPINEBTC
# Collecting data for DOTETH...
# Data saved for DOTETH
# Collecting data for STXBNB...
# Data saved for STXBNB
# Collecting data for SXPBTC...
# Data saved for SXPBTC
# Collecting data for BLZFDUSD...
# Data saved for BLZFDUSD
# Collecting data for ETHTUSD...
# Data saved for ETHTUSD
# Collecting data for BTSBTC...
# Data saved for BTSBTC
# Collecting data for LUNABNB...
# Data saved for LUNABNB
# Collecting data for FETBNB...
# Data saved for FETBNB
# Collecting data for IDEUR...
# Data saved for IDEUR
# Collecting data for REIBUSD...
# Data saved for REIBUSD
# Collecting data for NEARUSDC...
# Collecting data for VOXELBNB...
# Data saved for VOXELBNB
# Collecting data for EOSEUR...
# Data saved for EOSEUR
# Collecting data for SOLFDUSD...
# Data saved for SOLFDUSD
# Collecting data for ARBBTC...
# Data saved for ARBBTC
# Collecting data for VETBUSD...
# Data saved for VETBUSD
# Collecting data for RGTBTC...
# Data saved for RGTBTC
# Collecting data for FTTETH...
# Data saved for FTTETH
# Collecting data for FIDABTC...
# Data saved for FIDABTC
# Collecting data for BNBBTC...
# Data saved for BNBBTC
# Collecting data for STMXBUSD...
# Data saved for STMXBUSD
# Collecting data for WAVESETH...
# Data saved for WAVESETH
# Collecting data for CTXCBTC...
# Data saved for CTXCBTC
# Collecting data for NTRNBTC...
# Data saved for NTRNBTC
# Collecting data for VITEBNB...
# Data saved for VITEBNB
# Collecting data for LTOBTC...
# Data saved for LTOBTC
# Collecting data for ATOMUSDC...
# Data saved for ATOMUSDC
# Collecting data for ELFETH...
# Data saved for ELFETH
# Collecting data for VIDTBTC...
# Data saved for VIDTBTC
# Collecting data for WINGETH...
# Data saved for WINGETH
# Collecting data for MDTBNB...
# Data saved for MDTBNB
# Collecting data for EGLDEUR...
# Data saved for EGLDEUR
# Collecting data for STORJBTC...
# Data saved for STORJBTC
# Collecting data for COSBTC...
# Data saved for COSBTC
# Collecting data for XMRBNB...
# Data saved for XMRBNB
# Collecting data for SOLAUD...
# Data saved for SOLAUD
# Collecting data for BNBGBP...
# Data saved for BNBGBP
# Collecting data for FARMETH...
# Data saved for FARMETH
# Collecting data for SNXETH...
# Data saved for SNXETH
# Collecting data for AUDIOBUSD...
# Data saved for AUDIOBUSD
# Collecting data for MLNBTC...
# Data saved for MLNBTC
# Collecting data for API3BNB...
# Data saved for API3BNB
# Collecting data for PSGBUSD...
# Data saved for PSGBUSD
# Collecting data for APTEUR...
# Data saved for APTEUR
# Collecting data for REPBTC...
# Data saved for REPBTC
# Collecting data for DEGOBTC...
# Data saved for DEGOBTC
# Collecting data for WLDUSDC...
# Collecting data for TORNBUSD...
# Data saved for TORNBUSD
# Collecting data for STPTBUSD...
# Data saved for STPTBUSD
# Collecting data for QKCBUSD...
# Data saved for QKCBUSD
# Collecting data for UFTBUSD...
# Data saved for UFTBUSD
# Collecting data for IOTABUSD...
# Data saved for IOTABUSD
# Collecting data for PLABTC...
# Data saved for PLABTC
# Collecting data for DUSKBUSD...
# Data saved for DUSKBUSD
# Collecting data for UNIBNB...
# Data saved for UNIBNB
# Collecting data for FLMBUSD...
# Data saved for FLMBUSD
# Collecting data for LTCPAX...
# Data saved for LTCPAX
# Collecting data for ZENETH...
# Data saved for ZENETH
# Collecting data for KP3RBNB...
# Data saved for KP3RBNB
# Collecting data for EDUEUR...
# Data saved for EDUEUR
# Collecting data for STORMBNB...
# Data saved for STORMBNB
# Collecting data for HFTBUSD...
# Data saved for HFTBUSD
# Collecting data for BETHETH...
# Data saved for BETHETH
# Collecting data for ATABTC...
# Data saved for ATABTC
# Collecting data for GMTAUD...
# Data saved for GMTAUD
# Collecting data for FTMUSDC...
# Data saved for FTMUSDC
# Collecting data for ARDRBNB...
# Data saved for ARDRBNB
# Collecting data for RUNEBUSD...
# Data saved for RUNEBUSD
# Collecting data for GTOUSDC...
# Data saved for GTOUSDC
# Collecting data for AUDIOBTC...
# Data saved for AUDIOBTC
# Collecting data for ANKRBUSD...
# Data saved for ANKRBUSD
# Collecting data for PAXETH...
# Collecting data for LQTYFDUSD...
# Collecting data for HCETH...
# Data saved for HCETH
# Collecting data for AAVEETH...
# Data saved for AAVEETH
# Collecting data for GLMRBUSD...
# Data saved for GLMRBUSD
# Collecting data for CVXBTC...
# Data saved for CVXBTC
# Collecting data for ARKMBTC...
# Data saved for ARKMBTC
# Collecting data for NUBNB...
# Data saved for NUBNB
# Collecting data for VETBNB...
# Data saved for VETBNB
# Collecting data for ZRXETH...
# Data saved for ZRXETH
# Collecting data for DODOBTC...
# Data saved for DODOBTC
# Collecting data for LTCBTC...
# Data saved for LTCBTC
# Collecting data for LUNABUSD...
# Data saved for LUNABUSD
# Collecting data for AAVEBTC...
# Data saved for AAVEBTC
# Collecting data for BNBTUSD...
# Data saved for BNBTUSD
# Collecting data for SCRTBTC...
# Data saved for SCRTBTC
# Collecting data for TWTBUSD...
# Data saved for TWTBUSD
# Collecting data for ONETUSD...
# Data saved for ONETUSD
# Collecting data for TLMBTC...
# Data saved for TLMBTC
# Collecting data for RNDREUR...
# Collecting data for SHIBAUD...
# Data saved for SHIBAUD
# Collecting data for OOKIETH...
# Data saved for OOKIETH
# Collecting data for BTCDAI...
# Data saved for BTCDAI
# Collecting data for CTSIBUSD...
# Data saved for CTSIBUSD
# Collecting data for CHESSBUSD...
# Data saved for CHESSBUSD
# Collecting data for VIBBUSD...
# Data saved for VIBBUSD
# Collecting data for CITYBTC...
# Data saved for CITYBTC
# Collecting data for ATOMETH...
# Data saved for ATOMETH
# Collecting data for INJFDUSD...
# Data saved for INJFDUSD
# Collecting data for TFUELUSDC...
# Data saved for TFUELUSDC
# Collecting data for PAXBTC...
# Collecting data for HIGHBUSD...
# Data saved for HIGHBUSD
# Collecting data for LINKGBP...
# Data saved for LINKGBP
# Collecting data for SNXBTC...
# Data saved for SNXBTC
# Collecting data for HOTEUR...
# Data saved for HOTEUR
# Collecting data for SOLBTC...
# Data saved for SOLBTC
# Collecting data for GLMETH...
# Data saved for GLMETH
# Collecting data for SYSBUSD...
# Data saved for SYSBUSD
# Collecting data for APTBUSD...
# Data saved for APTBUSD
# Collecting data for RLCBNB...
# Data saved for RLCBNB
# Collecting data for JUVBTC...
# Data saved for JUVBTC
# Collecting data for BELBUSD...
# Data saved for BELBUSD
# Collecting data for BETABTC...
# Data saved for BETABTC
# Collecting data for ATOMPAX...
# Data saved for ATOMPAX
# Collecting data for WBETHETH...
# Data saved for WBETHETH
# Collecting data for FRONTUSDC...
# Collecting data for DGBBUSD...
# Data saved for DGBBUSD
# Collecting data for UMABUSD...
# Data saved for UMABUSD
# Collecting data for LUNCBUSD...
# Data saved for LUNCBUSD
# Collecting data for SUIUSDC...
# Collecting data for CTSIBNB...
# Data saved for CTSIBNB
# Collecting data for MATICFDUSD...
# Data saved for MATICFDUSD
# Collecting data for ARBNB...
# Data saved for ARBNB
# Collecting data for ALGOETH...
# Data saved for ALGOETH
# Collecting data for BIFIBNB...
# Data saved for BIFIBNB
# Collecting data for ZILBTC...
# Data saved for ZILBTC
# Collecting data for CAKETUSD...
# Data saved for CAKETUSD
# Collecting data for GFTBUSD...
# Data saved for GFTBUSD
# Collecting data for KAVABTC...
# Data saved for KAVABTC
# Collecting data for RNDRUSDC...
# Collecting data for UTKBTC...
# Data saved for UTKBTC
# Collecting data for SHIBTUSD...
# Data saved for SHIBTUSD
#
# All data has been saved to binance_pairs_2018-12-31_2024-01-01_1d.csv

# %%
data2 = pd.read_csv("binance_pairs_2018-12-31_2024-01-01_1d.csv")
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183125 entries, 0 to 1183124
# Data columns (total 13 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   symbol           1183125 non-null  object
#  1   open_time        1183125 non-null  object
#  2   open             1183125 non-null  float64
#  3   high             1183125 non-null  float64
#  4   low              1183125 non-null  float64
#  5   close            1183125 non-null  float64
#  6   volume           1183125 non-null  float64
#  7   close_time       1183125 non-null  object
#  8   quote_volume     1183125 non-null  float64
#  9   num_trades       1183125 non-null  int64
#  10  taker_base_vol   1183125 non-null  float64
#  11  taker_quote_vol  1183125 non-null  float64
#  12  ignore           1183125 non-null  int64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 117.3+ MB

# %%
data2.head()
# Out:
#           symbol   open_time  open  high  low  close        volume  \
# 0  1000SATSFDUSD  2023-12-12  0.00  0.00 0.00   0.00 4602853555.00
# 1  1000SATSFDUSD  2023-12-13  0.00  0.00 0.00   0.00 1881940994.00
# 2  1000SATSFDUSD  2023-12-14  0.00  0.00 0.00   0.00 4352983453.00
# 3  1000SATSFDUSD  2023-12-15  0.00  0.00 0.00   0.00 5927834603.00
# 4  1000SATSFDUSD  2023-12-16  0.00  0.00 0.00   0.00 3099592602.00
#
#                 close_time  quote_volume  num_trades  taker_base_vol  \
# 0  2023-12-12 23:59:59.999    2525021.75       14569   1910950521.00
# 1  2023-12-13 23:59:59.999     929487.73        7854    885572160.00
# 2  2023-12-14 23:59:59.999    2879741.83       23802   2009894457.00
# 3  2023-12-15 23:59:59.999    4821470.11       42360   2461870666.00
# 4  2023-12-16 23:59:59.999    2421713.32       13674   1532193355.00
#
#    taker_quote_vol  ignore
# 0       1047349.26       0
# 1        438627.10       0
# 2       1336631.79       0
# 3       2014572.02       0
# 4       1207083.82       0

# %%
# Convert time columns to datetime
data2['open_time'] = pd.to_datetime(data2['open_time'])
data2['close_time'] = pd.to_datetime(data2['close_time'])

data2.describe(include='all')
# Out:
#          symbol                      open_time        open        high  \
# count   1183125                        1183125  1183125.00  1183125.00
# unique     1476                            NaN         NaN         NaN
# top      BNBETH                            NaN         NaN         NaN
# freq       1827                            NaN         NaN         NaN
# mean        NaN  2021-12-18 15:28:43.207607808     4122.45     4231.70
# min         NaN            2019-01-01 00:00:00        0.00        0.00
# 25%         NaN            2021-01-29 00:00:00        0.00        0.00
# 50%         NaN            2022-02-23 00:00:00        0.00        0.00
# 75%         NaN            2023-01-01 00:00:00        0.48        0.51
# max         NaN            2024-01-01 00:00:00 47615392.00 48113580.00
# std         NaN                            NaN   260478.57   268697.48
#
#                low       close            volume  \
# count   1183125.00  1183125.00        1183125.00
# unique         NaN         NaN               NaN
# top            NaN         NaN               NaN
# freq           NaN         NaN               NaN
# mean       4002.99     4151.60     3083102918.31
# min           0.00        0.00              0.00
# 25%           0.00        0.00          39804.91
# 50%           0.00        0.00         389698.68
# 75%           0.46        0.48        3467383.00
# max    45021551.00 47615392.00 50522076714408.00
# std      250677.64   263155.76   148535868560.56
#
#                            close_time  quote_volume  num_trades  \
# count                         1183125    1183125.00  1183125.00
# unique                            NaN           NaN         NaN
# top                               NaN           NaN         NaN
# freq                              NaN           NaN         NaN
# mean    2021-12-19 15:27:52.089231360    3513650.57    10269.67
# min        2019-01-01 23:59:59.999000          0.00        0.00
# 25%     2021-01-29 23:59:59.999000064         37.61      670.00
# 50%     2022-02-23 23:59:59.999000064        690.55     2035.00
# 75%     2023-01-01 23:59:59.999000064     195538.89     6150.00
# max        2024-01-01 23:59:59.999000 7278601783.28 20117333.00
# std                               NaN   54986318.67    66687.04
#
#           taker_base_vol  taker_quote_vol     ignore
# count         1183125.00       1183125.00 1183125.00
# unique               NaN              NaN        NaN
# top                  NaN              NaN        NaN
# freq                 NaN              NaN        NaN
# mean       1536250699.22       1745375.21       0.00
# min                 0.00             0.00       0.00
# 25%             18339.60            17.70       0.00
# 50%            183563.81           328.13       0.00
# 75%           1652017.00         92737.26       0.00
# max    25171293531170.00    3583831756.36       0.00
# std       74420348371.34      27413132.71       0.00
